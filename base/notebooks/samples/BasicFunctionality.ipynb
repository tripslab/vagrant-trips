# %%
from genesis.tools.trips import ontology as ont
from genesis.tools.lextagger import lookup_all

# %%
ont

# %%
ont.data
# Out:
# {'spiciness-scale': ont::spiciness-scale,
#  'desirable-val': ont::desirable-val,
#  'not-usable-val': ont::not-usable-val,
#  'degree': ont::degree,
#  'sorry': ont::sorry,
#  'calc-multiply': ont::calc-multiply,
#  'addressee': ont::addressee,
#  'winter': ont::winter,
#  'stroke': ont::stroke,
#  'pos-soft-emotional-val': ont::pos-soft-emotional-val,
#  'prize': ont::prize,
#  'possible': ont::possible,
#  'dirty-val': ont::dirty-val,
#  'country': ont::country,
#  'male-child': ont::male-child,
#  'intrinsic-val': ont::intrinsic-val,
#  'less-val': ont::less-val,
#  'display': ont::display,
#  'care': ont::care,
#  'health-care-facility': ont::health-care-facility,
#  'sweaty-val': ont::sweaty-val,
#  'time-unit': ont::time-unit,
#  'ratio-scale': ont::ratio-scale,
#  'position': ont::position,
#  'speed-unit': ont::speed-unit,
#  'possess': ont::possess,
#  'arrange-text': ont::arrange-text,
#  'dimensional-property-val': ont::dimensional-property-val,
#  'domain-property': ont::domain-property,
#  'sourness-scale': ont::sourness-scale,
#  'internal-enclosure': ont::internal-enclosure,
#  'linguistic-val': ont::linguistic-val,
#  'inactive': ont::inactive,
#  'adjust-to-extreme': ont::adjust-to-extreme,
#  'origin': ont::origin,
#  'molecular-part': ont::molecular-part,
#  'circular-move': ont::circular-move,
#  'self-locomote': ont::self-locomote,
#  'desirous': ont::desirous,
#  'lightweight': ont::lightweight,
#  'sa_suggest': ont::sa_suggest,
#  'full': ont::full,
#  'medical-procedure': ont::medical-procedure,
#  'physical-property-val': ont::physical-property-val,
#  'not-certain-scale': ont::not-certain-scale,
#  'destination': ont::destination,
#  'width-scale': ont::width-scale,
#  'click': ont::click,
#  'dent': ont::dent,
#  'decrease-speed': ont::decrease-speed,
#  'moisture-content-scale': ont::moisture-content-scale,
#  'seafood': ont::seafood,
#  'configuration-property-val': ont::configuration-property-val,
#  'quick-relief-drug': ont::quick-relief-drug,
#  'smoking': ont::smoking,
#  'certainty-scale': ont::certainty-scale,
#  'red': ont::red,
#  'importance-scale': ont::importance-scale,
#  'envying': ont::envying,
#  'date-object-in': ont::date-object-in,
#  'clothedness-val': ont::clothedness-val,
#  'dry-val': ont::dry-val,
#  'inactive-closed': ont::inactive-closed,
#  'social-event': ont::social-event,
#  'sweet-val': ont::sweet-val,
#  'boldness-val': ont::boldness-val,
#  'combine-objects': ont::combine-objects,
#  'voltage-scale': ont::voltage-scale,
#  'unit': ont::unit,
#  'medical-condition-property-val': ont::medical-condition-property-val,
#  'evoke-fear': ont::evoke-fear,
#  'direct-at': ont::direct-at,
#  'sufficiency': ont::sufficiency,
#  'perlocution': ont::perlocution,
#  'modern-val': ont::modern-val,
#  'physical-val': ont::physical-val,
#  'injury-property-val': ont::injury-property-val,
#  'internal-authority': ont::internal-authority,
#  'sequence': ont::sequence,
#  'destroy': ont::destroy,
#  'information-property-val': ont::information-property-val,
#  'manner': ont::manner,
#  'urban-val': ont::urban-val,
#  'active': ont::active,
#  'persistence-val': ont::persistence-val,
#  'share': ont::share,
#  'activity-val': ont::activity-val,
#  'ancient-val': ont::ancient-val,
#  'direction-up-ground': ont::direction-up-ground,
#  'memory-unit': ont::memory-unit,
#  'methylation': ont::methylation,
#  'solve': ont::solve,
#  'brightness-scale': ont::brightness-scale,
#  'constipation': ont::constipation,
#  'counterclockwise': ont::counterclockwise,
#  'first-val': ont::first-val,
#  'direction-backward': ont::direction-backward,
#  'such': ont::such,
#  'computer-make': ont::computer-make,
#  'text-field': ont::text-field,
#  'describe': ont::describe,
#  'unwilling': ont::unwilling,
#  'protocol': ont::protocol,
#  'cause-move': ont::cause-move,
#  'dissolve': ont::dissolve,
#  'availability-val': ont::availability-val,
#  'beef': ont::beef,
#  'poultry': ont::poultry,
#  'sa_thank': ont::sa_thank,
#  'north': ont::north,
#  'select': ont::select,
#  'distress-scale': ont::distress-scale,
#  'agent-interaction': ont::agent-interaction,
#  'managing': ont::managing,
#  'butter': ont::butter,
#  'easy-scale': ont::easy-scale,
#  'enjoyable-val': ont::enjoyable-val,
#  'mine': ont::mine,
#  'bet': ont::bet,
#  'spasm': ont::spasm,
#  'supernatural-being': ont::supernatural-being,
#  'prepare': ont::prepare,
#  'dressings-sauces-coatings': ont::dressings-sauces-coatings,
#  'not-sensible-val': ont::not-sensible-val,
#  'addiction': ont::addiction,
#  'improve': ont::improve,
#  'bike': ont::bike,
#  'eater': ont::eater,
#  'density-scale': ont::density-scale,
#  'evoke-physical': ont::evoke-physical,
#  'replacement': ont::replacement,
#  'mental-psychological-illness-or-disorder': ont::mental-psychological-illness-or-disorder,
#  'color-scale': ont::color-scale,
#  'path': ont::path,
#  'break-object': ont::break-object,
#  'completely': ont::completely,
#  'mail': ont::mail,
#  'eager-val': ont::eager-val,
#  'beneficiary': ont::beneficiary,
#  'chicken': ont::chicken,
#  'in-loc': ont::in-loc,
#  'come-to-understand': ont::come-to-understand,
#  'device-component': ont::device-component,
#  'not-careful-val': ont::not-careful-val,
#  'lengthen': ont::lengthen,
#  'medical-diagnostic': ont::medical-diagnostic,
#  'software-feature': ont::software-feature,
#  'version': ont::version,
#  'near-reln': ont::near-reln,
#  'meat-other': ont::meat-other,
#  'anatomy': ont::anatomy,
#  'texture-scale': ont::texture-scale,
#  'complete': ont::complete,
#  'associated-with-science-val': ont::associated-with-science-val,
#  'amino-acid': ont::amino-acid,
#  'clause-condition': ont::clause-condition,
#  'conventional-speech-act': ont::conventional-speech-act,
#  'day': ont::day,
#  'cardinal-direction': ont::cardinal-direction,
#  'arrhythmia': ont::arrhythmia,
#  'on': ont::on,
#  'nominate': ont::nominate,
#  'pained-val': ont::pained-val,
#  'crater': ont::crater,
#  'purple': ont::purple,
#  'tiny': ont::tiny,
#  'tightness-scale': ont::tightness-scale,
#  'mental-val': ont::mental-val,
#  'repetition': ont::repetition,
#  'freshwater-fish': ont::freshwater-fish,
#  'route-topology-val': ont::route-topology-val,
#  'consume': ont::consume,
#  'not-possible-val': ont::not-possible-val,
#  'harmful-agency': ont::harmful-agency,
#  'whole-step': ont::whole-step,
#  'weight-val': ont::weight-val,
#  'military-group-abstr': ont::military-group-abstr,
#  'steady-scale': ont::steady-scale,
#  'instrument': ont::instrument,
#  'preferred-val': ont::preferred-val,
#  'ability-val': ont::ability-val,
#  'efficiency-val': ont::efficiency-val,
#  'confusion-scale': ont::confusion-scale,
#  'burner': ont::burner,
#  'container': ont::container,
#  'triple': ont::triple,
#  'away': ont::away,
#  'die': ont::die,
#  'confirm': ont::confirm,
#  'di-val': ont::di-val,
#  'actuality-val': ont::actuality-val,
#  'suppose': ont::suppose,
#  'situated-in': ont::situated-in,
#  'evoke-pain': ont::evoke-pain,
#  'revenue': ont::revenue,
#  'have': ont::have,
#  'ebola': ont::ebola,
#  'more-than-rel': ont::more-than-rel,
#  'essential-contract': ont::essential-contract,
#  'doubt': ont::doubt,
#  'geometric-relationship-val': ont::geometric-relationship-val,
#  'artificiality-val': ont::artificiality-val,
#  'tall-val': ont::tall-val,
#  'inhibit-effect': ont::inhibit-effect,
#  'bad': ont::bad,
#  'equal': ont::equal,
#  'highway': ont::highway,
#  'financial-institution': ont::financial-institution,
#  'evoke-emotion': ont::evoke-emotion,
#  'professional-organization': ont::professional-organization,
#  'inhaler': ont::inhaler,
#  'natural-substance': ont::natural-substance,
#  'visibility-scale': ont::visibility-scale,
#  'internet-organization': ont::internet-organization,
#  'pork': ont::pork,
#  'angle-unit': ont::angle-unit,
#  'answer': ont::answer,
#  'collective-val': ont::collective-val,
#  'typical-val': ont::typical-val,
#  'establish': ont::establish,
#  'obstructed': ont::obstructed,
#  'intangibility-scale': ont::intangibility-scale,
#  'configuration-property-scale': ont::configuration-property-scale,
#  'cause-action': ont::cause-action,
#  'strengthen': ont::strengthen,
#  'pos-wrt-containment-reln': ont::pos-wrt-containment-reln,
#  'crackers': ont::crackers,
#  'discard': ont::discard,
#  'offensiveness-val': ont::offensiveness-val,
#  'problem': ont::problem,
#  'usability-val': ont::usability-val,
#  'assoc-with': ont::assoc-with,
#  'good': ont::good,
#  'distance-scale': ont::distance-scale,
#  'infamous-val': ont::infamous-val,
#  'tanker': ont::tanker,
#  'short-val': ont::short-val,
#  'length-scale': ont::length-scale,
#  'south-reln': ont::south-reln,
#  'event-event-time': ont::event-event-time,
#  'n-plex-val': ont::n-plex-val,
#  'propel': ont::propel,
#  'computer-firmware': ont::computer-firmware,
#  'relevance-val': ont::relevance-val,
#  'spoon': ont::spoon,
#  'meaningfulness-val': ont::meaningfulness-val,
#  'cure': ont::cure,
#  'pos-extended-along-linear-area': ont::pos-extended-along-linear-area,
#  'body-condition-scale': ont::body-condition-scale,
#  'religion-related-val': ont::religion-related-val,
#  'coma': ont::coma,
#  'kill': ont::kill,
#  'change-integrity': ont::change-integrity,
#  'similar': ont::similar,
#  'envious': ont::envious,
#  'air-vehicle': ont::air-vehicle,
#  'family-group': ont::family-group,
#  'cope-deal': ont::cope-deal,
#  'pos-wrt-speaker-reln': ont::pos-wrt-speaker-reln,
#  'biological-role': ont::biological-role,
#  'reliability-val': ont::reliability-val,
#  'content': ont::content,
#  'medium-val': ont::medium-val,
#  'highlight': ont::highlight,
#  'appliance': ont::appliance,
#  'artificial': ont::artificial,
#  'temporal-modifier': ont::temporal-modifier,
#  'chill': ont::chill,
#  'expandable-val': ont::expandable-val,
#  'research-facility': ont::research-facility,
#  'package': ont::package,
#  'sound-unit': ont::sound-unit,
#  'position-wrt-area-reln': ont::position-wrt-area-reln,
#  'medication': ont::medication,
#  'apologize': ont::apologize,
#  'tastable-property-val': ont::tastable-property-val,
#  'revise': ont::revise,
#  'office-supply-company-abstr': ont::office-supply-company-abstr,
#  'attitude-of-belief': ont::attitude-of-belief,
#  'joining': ont::joining,
#  'goose': ont::goose,
#  'loudness-val': ont::loudness-val,
#  'leaning': ont::leaning,
#  'finalized-val': ont::finalized-val,
#  'specificity-val': ont::specificity-val,
#  'object-dependent-location': ont::object-dependent-location,
#  'predictability-val': ont::predictability-val,
#  'silver': ont::silver,
#  'requirement-scale': ont::requirement-scale,
#  'gray': ont::gray,
#  'return': ont::return,
#  'chemical-val': ont::chemical-val,
#  'insanity': ont::insanity,
#  'anxiety': ont::anxiety,
#  'entering': ont::entering,
#  'recommendability-val': ont::recommendability-val,
#  'choosing': ont::choosing,
#  'visual-dullness-scale': ont::visual-dullness-scale,
#  'north-reln': ont::north-reln,
#  'seizure': ont::seizure,
#  'loaded-claim': ont::loaded-claim,
#  'tangible-abstract-object': ont::tangible-abstract-object,
#  'temperature-val': ont::temperature-val,
#  'vertebrate': ont::vertebrate,
#  'move-forward': ont::move-forward,
#  'take-incrementally': ont::take-incrementally,
#  'orange': ont::orange,
#  'meaningful-val': ont::meaningful-val,
#  'interval-duration-modifier': ont::interval-duration-modifier,
#  'similarity-val': ont::similarity-val,
#  'take-time': ont::take-time,
#  'leave-time': ont::leave-time,
#  'fitness-scale': ont::fitness-scale,
#  'reprimand': ont::reprimand,
#  'endpoint': ont::endpoint,
#  'change-format': ont::change-format,
#  'loudness-scale': ont::loudness-scale,
#  'positive-emotion-scale': ont::positive-emotion-scale,
#  'not-steady-scale': ont::not-steady-scale,
#  'row-formation': ont::row-formation,
#  'thankfulness-val': ont::thankfulness-val,
#  'smoothen': ont::smoothen,
#  'sound-scale': ont::sound-scale,
#  'alert-val': ont::alert-val,
#  'change': ont::change,
#  'change-magnitude': ont::change-magnitude,
#  'ability-scale': ont::ability-scale,
#  'opinion': ont::opinion,
#  'edema': ont::edema,
#  'kind': ont::kind,
#  'accommodation': ont::accommodation,
#  'evoke-compliance': ont::evoke-compliance,
#  'geo-formation': ont::geo-formation,
#  'body-related-property-val': ont::body-related-property-val,
#  'formation': ont::formation,
#  'noisy': ont::noisy,
#  'evoke-discomfort': ont::evoke-discomfort,
#  'truck': ont::truck,
#  'farm': ont::farm,
#  'goal-reln': ont::goal-reln,
#  'refuse': ont::refuse,
#  'evoke-attraction': ont::evoke-attraction,
#  'female-child': ont::female-child,
#  'time-rel-so-far': ont::time-rel-so-far,
#  'incorrect': ont::incorrect,
#  'definition': ont::definition,
#  'light-val': ont::light-val,
#  'medical-dehydration-val': ont::medical-dehydration-val,
#  'politeness': ont::politeness,
#  'atmospheric-scale': ont::atmospheric-scale,
#  'avoid-location': ont::avoid-location,
#  'capture': ont::capture,
#  'boring': ont::boring,
#  'title': ont::title,
#  'pos-as-opposite': ont::pos-as-opposite,
#  'expensive-scale': ont::expensive-scale,
#  'offer': ont::offer,
#  'jaunt': ont::jaunt,
#  'move-back-and-forth': ont::move-back-and-forth,
#  'poly-val': ont::poly-val,
#  'awkward-val': ont::awkward-val,
#  'specific-val': ont::specific-val,
#  'linguistic-object': ont::linguistic-object,
#  'objective-influence': ont::objective-influence,
#  'at-loc': ont::at-loc,
#  'person': ont::person,
#  'degree-modifier-med': ont::degree-modifier-med,
#  'convenient-val': ont::convenient-val,
#  'sensory-mode-val': ont::sensory-mode-val,
#  'natural': ont::natural,
#  'historical-era-val': ont::historical-era-val,
#  'effective-val': ont::effective-val,
#  'astronomy-val': ont::astronomy-val,
#  'not-tolerable-val': ont::not-tolerable-val,
#  'path-shape': ont::path-shape,
#  'social-group': ont::social-group,
#  'harmfulness-val': ont::harmfulness-val,
#  'in-touch-val': ont::in-touch-val,
#  'cover': ont::cover,
#  'communication-channel': ont::communication-channel,
#  'direction-forward': ont::direction-forward,
#  'lacking': ont::lacking,
#  'truth-value-val': ont::truth-value-val,
#  'correctness-scale': ont::correctness-scale,
#  'setting': ont::setting,
#  'optical-device': ont::optical-device,
#  'direction-down-ground': ont::direction-down-ground,
#  'end-at-loc': ont::end-at-loc,
#  'hives': ont::hives,
#  'event-of-change': ont::event-of-change,
#  'should': ont::should,
#  'time-duration-rel': ont::time-duration-rel,
#  'texture-val': ont::texture-val,
#  'perceptual-construction': ont::perceptual-construction,
#  'managing-resources': ont::managing-resources,
#  'osteoporosis': ont::osteoporosis,
#  'cloudy': ont::cloudy,
#  'health-professional': ont::health-professional,
#  'neg': ont::neg,
#  'shrink': ont::shrink,
#  'gracefulness-val': ont::gracefulness-val,
#  'position-reln': ont::position-reln,
#  'protecting': ont::protecting,
#  'feeding': ont::feeding,
#  'dehydrated-scale': ont::dehydrated-scale,
#  'swell': ont::swell,
#  'steady': ont::steady,
#  'temperature-unit': ont::temperature-unit,
#  'conventional-position-reln': ont::conventional-position-reln,
#  'tactile-hardness-scale': ont::tactile-hardness-scale,
#  'adorned-val': ont::adorned-val,
#  'bad-aesthetic-judgement-val': ont::bad-aesthetic-judgement-val,
#  'not-familiar': ont::not-familiar,
#  'performance-play': ont::performance-play,
#  'certain-scale': ont::certain-scale,
#  'ability-to-taste': ont::ability-to-taste,
#  'regularity-scale': ont::regularity-scale,
#  'linear-extent-scale': ont::linear-extent-scale,
#  'come': ont::come,
#  'substance': ont::substance,
#  'choice-option': ont::choice-option,
#  'pressure-scale': ont::pressure-scale,
#  'exists': ont::exists,
#  'etcetera': ont::etcetera,
#  'mathematical-term': ont::mathematical-term,
#  'parts-removed': ont::parts-removed,
#  'dead': ont::dead,
#  'group-object-abstr': ont::group-object-abstr,
#  'sa_close': ont::sa_close,
#  'authenticity-val': ont::authenticity-val,
#  'visible-property-val': ont::visible-property-val,
#  'furnishings': ont::furnishings,
#  'allows-doing-val': ont::allows-doing-val,
#  'mechanical-val': ont::mechanical-val,
#  'unhappy': ont::unhappy,
#  'texture-thinness-scale': ont::texture-thinness-scale,
#  'prohibit': ont::prohibit,
#  'interesting-val': ont::interesting-val,
#  'proportion-val': ont::proportion-val,
#  'assume': ont::assume,
#  'proposal': ont::proposal,
#  'fast-food': ont::fast-food,
#  'adjust': ont::adjust,
#  'software-company-abstr': ont::software-company-abstr,
#  'omit': ont::omit,
#  'quantity': ont::quantity,
#  'badness-scale': ont::badness-scale,
#  'passing': ont::passing,
#  'truth-scale': ont::truth-scale,
#  'bacterium': ont::bacterium,
#  'pause': ont::pause,
#  'collection-abstr': ont::collection-abstr,
#  'flatter': ont::flatter,
#  'sport': ont::sport,
#  'squeeze': ont::squeeze,
#  'non-vertical-scale': ont::non-vertical-scale,
#  'food-prep-process': ont::food-prep-process,
#  'promoter': ont::promoter,
#  'down': ont::down,
#  'planet': ont::planet,
#  'direction-rotation': ont::direction-rotation,
#  'round-val': ont::round-val,
#  'adjacent': ont::adjacent,
#  'speedy': ont::speedy,
#  'sa_wh-question': ont::sa_wh-question,
#  'sequence-abstr': ont::sequence-abstr,
#  'social-interaction-val': ont::social-interaction-val,
#  'minimize': ont::minimize,
#  'social-practice': ont::social-practice,
#  'accept-agree': ont::accept-agree,
#  'backache': ont::backache,
#  'stay': ont::stay,
#  'emotion-scale': ont::emotion-scale,
#  'qualification': ont::qualification,
#  'satiated-val': ont::satiated-val,
#  'straightforward-val': ont::straightforward-val,
#  'cytosol': ont::cytosol,
#  'translocate': ont::translocate,
#  'associated-with-food-val': ont::associated-with-food-val,
#  'dissuade': ont::dissuade,
#  'phys-shape': ont::phys-shape,
#  'responsible-val': ont::responsible-val,
#  'dimension': ont::dimension,
#  'decrease-completely': ont::decrease-completely,
#  'phase': ont::phase,
#  'saltwater-fish': ont::saltwater-fish,
#  'commerce-collect': ont::commerce-collect,
#  'change-in-dimension': ont::change-in-dimension,
#  'residue': ont::residue,
#  'ps-object': ont::ps-object,
#  'weight-unit': ont::weight-unit,
#  'persistent': ont::persistent,
#  'tunnel': ont::tunnel,
#  'burn-out-light-up-change': ont::burn-out-light-up-change,
#  'spices-herbs': ont::spices-herbs,
#  'drought': ont::drought,
#  'relate': ont::relate,
#  'electronics-company': ont::electronics-company,
#  'cell-compartment': ont::cell-compartment,
#  'second-duration': ont::second-duration,
#  'excitement-scale': ont::excitement-scale,
#  'trust': ont::trust,
#  'bakery': ont::bakery,
#  'state-of-being': ont::state-of-being,
#  'letter-symbol': ont::letter-symbol,
#  'account': ont::account,
#  'uncertain': ont::uncertain,
#  'hypoglycemia': ont::hypoglycemia,
#  'chord': ont::chord,
#  'great-val': ont::great-val,
#  'presense-of-light-val': ont::presense-of-light-val,
#  'position-as-point-reln': ont::position-as-point-reln,
#  'farnesylation': ont::farnesylation,
#  'loose-val': ont::loose-val,
#  'go-on': ont::go-on,
#  'scout': ont::scout,
#  'awareness-val': ont::awareness-val,
#  'atmospheric-val': ont::atmospheric-val,
#  'group-object': ont::group-object,
#  'stop': ont::stop,
#  'repair': ont::repair,
#  'deselect': ont::deselect,
#  'long-term-control-drug': ont::long-term-control-drug,
#  'boxcar': ont::boxcar,
#  'perception': ont::perception,
#  'day-name': ont::day-name,
#  'alertness-val': ont::alertness-val,
#  'luminosity-val': ont::luminosity-val,
#  'acoustic-unit': ont::acoustic-unit,
#  'ordering': ont::ordering,
#  'computer-type': ont::computer-type,
#  'remove-from': ont::remove-from,
#  'membership': ont::membership,
#  'correctness-val': ont::correctness-val,
#  'peripheral-val': ont::peripheral-val,
#  'situation-object-modifier': ont::situation-object-modifier,
#  'kissing': ont::kissing,
#  'username': ont::username,
#  'olfactory-scale': ont::olfactory-scale,
#  'restart': ont::restart,
#  'macromolecular-complex': ont::macromolecular-complex,
#  'affiliate-abstr': ont::affiliate-abstr,
#  'comfort-val': ont::comfort-val,
#  'commerce': ont::commerce,
#  'circumscribe': ont::circumscribe,
#  'quality-val': ont::quality-val,
#  'supplier': ont::supplier,
#  'clean-scale': ont::clean-scale,
#  'there': ont::there,
#  'sumoylation': ont::sumoylation,
#  'r-able-val': ont::r-able-val,
#  'unordered-domain': ont::unordered-domain,
#  'analog': ont::analog,
#  'button': ont::button,
#  'less-than-rel': ont::less-than-rel,
#  'public-service-facility': ont::public-service-facility,
#  'internal': ont::internal,
#  'craziness-scale': ont::craziness-scale,
#  'poverty': ont::poverty,
#  'towards': ont::towards,
#  'affixed-val': ont::affixed-val,
#  'reason-informal': ont::reason-informal,
#  'middle-val': ont::middle-val,
#  'city-rel': ont::city-rel,
#  'expensiveness': ont::expensiveness,
#  'increase-speed': ont::increase-speed,
#  'attributed-information': ont::attributed-information,
#  'not-precise-val': ont::not-precise-val,
#  'unattach': ont::unattach,
#  'orients-to': ont::orients-to,
#  'not-satiated-val': ont::not-satiated-val,
#  'attribute': ont::attribute,
#  'equal-scale': ont::equal-scale,
#  'weather': ont::weather,
#  'suitability-scale': ont::suitability-scale,
#  'condiments': ont::condiments,
#  'order': ont::order,
#  'interact': ont::interact,
#  'change-in-time-measure': ont::change-in-time-measure,
#  'quantity-abstr': ont::quantity-abstr,
#  'register': ont::register,
#  'consumer': ont::consumer,
#  'unsmellability-val': ont::unsmellability-val,
#  'predefined-size-val': ont::predefined-size-val,
#  'arthritis': ont::arthritis,
#  'state-of-worrying': ont::state-of-worrying,
#  'hidden': ont::hidden,
#  'geo-object': ont::geo-object,
#  'completeness-val': ont::completeness-val,
#  'mutant-obj': ont::mutant-obj,
#  'foreigner': ont::foreigner,
#  'vacation': ont::vacation,
#  'ask-question': ont::ask-question,
#  'sa_tell': ont::sa_tell,
#  'pigeon': ont::pigeon,
#  'zipcode': ont::zipcode,
#  'not-loose-val': ont::not-loose-val,
#  'symbolic-representation': ont::symbolic-representation,
#  'move-upward': ont::move-upward,
#  'wet-val': ont::wet-val,
#  'fever': ont::fever,
#  'stairs': ont::stairs,
#  'map': ont::map,
#  'event-of-experience': ont::event-of-experience,
#  'military-group': ont::military-group,
#  'change-in-ratio': ont::change-in-ratio,
#  'cause-body-effect': ont::cause-body-effect,
#  'direction-wrt-entity': ont::direction-wrt-entity,
#  'encourage': ont::encourage,
#  'change-in-physical-property-scale': ont::change-in-physical-property-scale,
#  'machine': ont::machine,
#  'west-reln': ont::west-reln,
#  'degree-modifier-low': ont::degree-modifier-low,
#  'dry': ont::dry,
#  'sa_go-offline': ont::sa_go-offline,
#  'rural-val': ont::rural-val,
#  'antibiotic': ont::antibiotic,
#  'useful': ont::useful,
#  'percent-scale': ont::percent-scale,
#  'voyage': ont::voyage,
#  'rub-scrape-wipe': ont::rub-scrape-wipe,
#  'superior-val': ont::superior-val,
#  'predefined-measure-scale': ont::predefined-measure-scale,
#  'moderate-val': ont::moderate-val,
#  'tighten': ont::tighten,
#  'temporal-occurrence-val': ont::temporal-occurrence-val,
#  'thinness-scale': ont::thinness-scale,
#  'not-verifiable-val': ont::not-verifiable-val,
#  'lastname': ont::lastname,
#  'robust-val': ont::robust-val,
#  'dyspepsia': ont::dyspepsia,
#  'small-container': ont::small-container,
#  'not-credible-val': ont::not-credible-val,
#  'novelty-val': ont::novelty-val,
#  'fame-val': ont::fame-val,
#  'conjunct': ont::conjunct,
#  'cleanliness-scale': ont::cleanliness-scale,
#  'foreign-val': ont::foreign-val,
#  'downtown': ont::downtown,
#  'tameness-val': ont::tameness-val,
#  'miss': ont::miss,
#  'kicking': ont::kicking,
#  'with-instrument': ont::with-instrument,
#  'not-compatible-val': ont::not-compatible-val,
#  'unclean-scale': ont::unclean-scale,
#  'nationality-val': ont::nationality-val,
#  'clever-val': ont::clever-val,
#  'driving-trip': ont::driving-trip,
#  'diarrhea': ont::diarrhea,
#  'condition': ont::condition,
#  'plainness-val': ont::plainness-val,
#  'direction-leftward': ont::direction-leftward,
#  'science-discipline': ont::science-discipline,
#  'constraint': ont::constraint,
#  'precipitation': ont::precipitation,
#  'appropriateness-val': ont::appropriateness-val,
#  'compete': ont::compete,
#  'hydrolysis': ont::hydrolysis,
#  'vertical-val': ont::vertical-val,
#  'standard': ont::standard,
#  'render-ineffective': ont::render-ineffective,
#  'pull': ont::pull,
#  'minute-duration': ont::minute-duration,
#  'deprive': ont::deprive,
#  'catch': ont::catch,
#  'material': ont::material,
#  'read': ont::read,
#  'move-downward': ont::move-downward,
#  'representation': ont::representation,
#  'future': ont::future,
#  'foolish-val': ont::foolish-val,
#  'loc-def-by-goal': ont::loc-def-by-goal,
#  'becoming-aware-of-value': ont::becoming-aware-of-value,
#  'land': ont::land,
#  'half-step': ont::half-step,
#  'route': ont::route,
#  'lightness-scale': ont::lightness-scale,
#  'not-free-val': ont::not-free-val,
#  'likely-scale': ont::likely-scale,
#  'praise': ont::praise,
#  'willing': ont::willing,
#  'freedom-val': ont::freedom-val,
#  'not-aware-val': ont::not-aware-val,
#  'punctuation': ont::punctuation,
#  'std-measurement-val': ont::std-measurement-val,
#  'validity-val': ont::validity-val,
#  'resolution-scale': ont::resolution-scale,
#  'attention-val': ont::attention-val,
#  'event-of-action': ont::event-of-action,
#  'academic-institution': ont::academic-institution,
#  'noticeable': ont::noticeable,
#  'any-sem': ont::any-sem,
#  'function-calculation': ont::function-calculation,
#  'insult': ont::insult,
#  'other': ont::other,
#  'blame': ont::blame,
#  'forget': ont::forget,
#  'computer-processor': ont::computer-processor,
#  'extend': ont::extend,
#  'information-scrutiny': ont::information-scrutiny,
#  'year-stage': ont::year-stage,
#  'utility': ont::utility,
#  'fire': ont::fire,
#  'familiar-val': ont::familiar-val,
#  'around': ont::around,
#  'weight-scale': ont::weight-scale,
#  'event-defined-by-activity': ont::event-defined-by-activity,
#  'could-be-at': ont::could-be-at,
#  'month': ont::month,
#  'plant-part': ont::plant-part,
#  'verifiable-val': ont::verifiable-val,
#  'brighten': ont::brighten,
#  'identity-val': ont::identity-val,
#  'cupboard': ont::cupboard,
#  'sampling': ont::sampling,
#  'duplicate': ont::duplicate,
#  'octave': ont::octave,
#  'support-stand': ont::support-stand,
#  'while': ont::while,
#  'minerals': ont::minerals,
#  'beautiful': ont::beautiful,
#  'acquire': ont::acquire,
#  'language-adjust': ont::language-adjust,
#  'skinny-val': ont::skinny-val,
#  'religious-facility': ont::religious-facility,
#  'plant': ont::plant,
#  'inverted-val': ont::inverted-val,
#  'manageable': ont::manageable,
#  'never': ont::never,
#  'hardness-val': ont::hardness-val,
#  'commerce-pay': ont::commerce-pay,
#  'neg-intense-emotional-val': ont::neg-intense-emotional-val,
#  'unsteady': ont::unsteady,
#  'pos-intense-emotional-val': ont::pos-intense-emotional-val,
#  'storm': ont::storm,
#  'evoke-excitement': ont::evoke-excitement,
#  'able': ont::able,
#  'sheet-abstr': ont::sheet-abstr,
#  'process-evaluation-scale': ont::process-evaluation-scale,
#  'adaptability-scale': ont::adaptability-scale,
#  'grade-score': ont::grade-score,
#  'different': ont::different,
#  'successor': ont::successor,
#  'identity-and-origin': ont::identity-and-origin,
#  'junior-val': ont::junior-val,
#  'no-cost-val': ont::no-cost-val,
#  'publication': ont::publication,
#  'nonverbal-expression': ont::nonverbal-expression,
#  'heat': ont::heat,
#  'cancer': ont::cancer,
#  'immerse': ont::immerse,
#  'stir': ont::stir,
#  'not-accessible-val': ont::not-accessible-val,
#  'below': ont::below,
#  'wear': ont::wear,
#  'filled-val': ont::filled-val,
#  'key': ont::key,
#  'era': ont::era,
#  'physical-sensation': ont::physical-sensation,
#  'change-in-tactile-scale': ont::change-in-tactile-scale,
#  'severity-scale': ont::severity-scale,
#  'evoke-comfort': ont::evoke-comfort,
#  'weigh': ont::weigh,
#  'regretting': ont::regretting,
#  'acknowledge': ont::acknowledge,
#  'anemia': ont::anemia,
#  'stones-disease': ont::stones-disease,
#  'has-medical-condition': ont::has-medical-condition,
#  'urgent-val': ont::urgent-val,
#  'pleasing-val': ont::pleasing-val,
#  'exchange': ont::exchange,
#  'row-formation-abstr': ont::row-formation-abstr,
#  'bronchodilator': ont::bronchodilator,
#  'body-movement': ont::body-movement,
#  'delimit-reln': ont::delimit-reln,
#  'time-defined-by-event': ont::time-defined-by-event,
#  'passive': ont::passive,
#  'encodes-message': ont::encodes-message,
#  'cancel': ont::cancel,
#  'calc-add': ont::calc-add,
#  'intentional-val': ont::intentional-val,
#  'prepared': ont::prepared,
#  'high-val': ont::high-val,
#  'commissive': ont::commissive,
#  'not-ambitious-val': ont::not-ambitious-val,
#  'vehicle-part': ont::vehicle-part,
#  'write': ont::write,
#  'sa_discourse-manage': ont::sa_discourse-manage,
#  'value-cost': ont::value-cost,
#  'assign': ont::assign,
#  'volume-measure-unit': ont::volume-measure-unit,
#  'height-scale': ont::height-scale,
#  'move-quickly': ont::move-quickly,
#  'argue': ont::argue,
#  'humid-warm-val': ont::humid-warm-val,
#  'commodity': ont::commodity,
#  'wheeze': ont::wheeze,
#  'column-formation-abstr': ont::column-formation-abstr,
#  'id-number': ont::id-number,
#  'time-condition': ont::time-condition,
#  'compatibility-val': ont::compatibility-val,
#  'wheel': ont::wheel,
#  'nutrient': ont::nutrient,
#  'contra': ont::contra,
#  'document': ont::document,
#  'arranging': ont::arranging,
#  'religious-region': ont::religious-region,
#  'worthy-val': ont::worthy-val,
#  'safety-val': ont::safety-val,
#  'windy-val': ont::windy-val,
#  'visual-clarity-scale': ont::visual-clarity-scale,
#  'messy-val': ont::messy-val,
#  'bodily-process': ont::bodily-process,
#  'money-scale': ont::money-scale,
#  'time-defined-by-duration': ont::time-defined-by-duration,
#  'employ': ont::employ,
#  'change-in-size': ont::change-in-size,
#  'ability-to-hear': ont::ability-to-hear,
#  'not-relevant-val': ont::not-relevant-val,
#  'ugly-scale': ont::ugly-scale,
#  'shortcut': ont::shortcut,
#  'area-scale': ont::area-scale,
#  'start': ont::start,
#  'bagels-biscuits': ont::bagels-biscuits,
#  'consistent': ont::consistent,
#  'evoke-hunger': ont::evoke-hunger,
#  'tank': ont::tank,
#  'shape-object': ont::shape-object,
#  'deliver': ont::deliver,
#  'state-of-affairs-scale': ont::state-of-affairs-scale,
#  'reveal': ont::reveal,
#  'loc-wrt-ground-as-spatial-obj': ont::loc-wrt-ground-as-spatial-obj,
#  'create': ont::create,
#  'occasional': ont::occasional,
#  'cause-out-of': ont::cause-out-of,
#  'allow': ont::allow,
#  'portable-val': ont::portable-val,
#  'wet-scale': ont::wet-scale,
#  'computer-model': ont::computer-model,
#  'participate-attend': ont::participate-attend,
#  'remaining-val': ont::remaining-val,
#  'seniority-val': ont::seniority-val,
#  'vitamins-minerals': ont::vitamins-minerals,
#  'device': ont::device,
#  'calc-divide': ont::calc-divide,
#  'restless-val': ont::restless-val,
#  'promise': ont::promise,
#  'productivity-val': ont::productivity-val,
#  'healthy-val': ont::healthy-val,
#  'rotate': ont::rotate,
#  'unclassified-val': ont::unclassified-val,
#  'usefulness-val': ont::usefulness-val,
#  'startoff-begin-commence-start': ont::startoff-begin-commence-start,
#  'aggressiveness-scale': ont::aggressiveness-scale,
#  'active-on': ont::active-on,
#  'aware-val': ont::aware-val,
#  'disperse': ont::disperse,
#  'ask': ont::ask,
#  'quiet': ont::quiet,
#  'reliability-scale': ont::reliability-scale,
#  'puzzled-val': ont::puzzled-val,
#  'euphoric': ont::euphoric,
#  'harden': ont::harden,
#  'manner-undo': ont::manner-undo,
#  'remove-parts': ont::remove-parts,
#  'whole-complete': ont::whole-complete,
#  'side-location-val': ont::side-location-val,
#  'invalid-val': ont::invalid-val,
#  'oriented-loc-reln': ont::oriented-loc-reln,
#  'amass': ont::amass,
#  'advise': ont::advise,
#  'organization-abstr': ont::organization-abstr,
#  'nychthemeron-event': ont::nychthemeron-event,
#  'ability': ont::ability,
#  'near': ont::near,
#  'visual-sharpness-scale': ont::visual-sharpness-scale,
#  'severity-val': ont::severity-val,
#  'clinical-finding': ont::clinical-finding,
#  'attribute-impute': ont::attribute-impute,
#  'audibility-val': ont::audibility-val,
#  'signature': ont::signature,
#  'lid': ont::lid,
#  'sort': ont::sort,
#  'white': ont::white,
#  'copy': ont::copy,
#  'remember': ont::remember,
#  'precision-val': ont::precision-val,
#  'palpitation': ont::palpitation,
#  'questioning': ont::questioning,
#  'acquire-belief': ont::acquire-belief,
#  'try-again': ont::try-again,
#  'incur-inherit-receive': ont::incur-inherit-receive,
#  'federal-val': ont::federal-val,
#  'drift': ont::drift,
#  'tangibility-val': ont::tangibility-val,
#  'computer-program': ont::computer-program,
#  'gene-transcription': ont::gene-transcription,
#  'appropriate': ont::appropriate,
#  'working-out': ont::working-out,
#  'land-vehicle': ont::land-vehicle,
#  'appreciate': ont::appreciate,
#  'grievous-val': ont::grievous-val,
#  'financial-organization-abstr': ont::financial-organization-abstr,
#  'kettle': ont::kettle,
#  'same-scale': ont::same-scale,
#  'quietness-scale': ont::quietness-scale,
#  'result': ont::result,
#  'speech-act': ont::speech-act,
#  'dehydrate': ont::dehydrate,
#  'through': ont::through,
#  'not-predictable-val': ont::not-predictable-val,
#  'computer-network-type': ont::computer-network-type,
#  'commerce-val': ont::commerce-val,
#  'rna': ont::rna,
#  'redness-scale': ont::redness-scale,
#  'skillfulness-scale': ont::skillfulness-scale,
#  'pardon': ont::pardon,
#  'microwave': ont::microwave,
#  'true-val': ont::true-val,
#  'exceptional-val': ont::exceptional-val,
#  'categorization': ont::categorization,
#  'hesitate': ont::hesitate,
#  'ride': ont::ride,
#  'disappear': ont::disappear,
#  'flooding': ont::flooding,
#  'physical-process': ont::physical-process,
#  'district': ont::district,
#  'flow-val': ont::flow-val,
#  'position-on-dimension-scale-val': ont::position-on-dimension-scale-val,
#  'having': ont::having,
#  'adapt': ont::adapt,
#  'lodging': ont::lodging,
#  'agitated': ont::agitated,
#  'insane': ont::insane,
#  'conventionality-val': ont::conventionality-val,
#  'assistant': ont::assistant,
#  'enlarge': ont::enlarge,
#  'related-to-cardinality-val': ont::related-to-cardinality-val,
#  'signal-representation-val': ont::signal-representation-val,
#  'sequence-position': ont::sequence-position,
#  'supplier-abstr': ont::supplier-abstr,
#  'adequacy-val': ont::adequacy-val,
#  'change-awareness': ont::change-awareness,
#  'salty-val': ont::salty-val,
#  'lane': ont::lane,
#  'evoke-clarity': ont::evoke-clarity,
#  'wild-game': ont::wild-game,
#  'singularity-val': ont::singularity-val,
#  'location': ont::location,
#  'conductor': ont::conductor,
#  'yellow': ont::yellow,
#  'fresh-val': ont::fresh-val,
#  'associated-information': ont::associated-information,
#  'year': ont::year,
#  'dimensional-scale': ont::dimensional-scale,
#  'able-scale': ont::able-scale,
#  'beverages': ont::beverages,
#  'composition': ont::composition,
#  'constriction-scale': ont::constriction-scale,
#  'binding-val': ont::binding-val,
#  'compatible-val': ont::compatible-val,
#  'distance-val': ont::distance-val,
#  'pulse': ont::pulse,
#  'exclude': ont::exclude,
#  'bright-val': ont::bright-val,
#  'trip-out': ont::trip-out,
#  'acquire-by-action': ont::acquire-by-action,
#  'without': ont::without,
#  'implicit-overlap': ont::implicit-overlap,
#  'disease': ont::disease,
#  'sa_nolo-comprendez': ont::sa_nolo-comprendez,
#  'cause-come-from': ont::cause-come-from,
#  'collaborate': ont::collaborate,
#  'relaxed-val': ont::relaxed-val,
#  'fuel': ont::fuel,
#  'summer': ont::summer,
#  'east-reln': ont::east-reln,
#  'process-evaluation-val': ont::process-evaluation-val,
#  'predictable-val': ont::predictable-val,
#  'intersect': ont::intersect,
#  'tow-truck': ont::tow-truck,
#  'chargeability-val': ont::chargeability-val,
#  'grateful': ont::grateful,
#  'fill-container': ont::fill-container,
#  'scholar': ont::scholar,
#  'lack': ont::lack,
#  'harmful-val': ont::harmful-val,
#  'working': ont::working,
#  'intelligence-val': ont::intelligence-val,
#  'can-be-done-val': ont::can-be-done-val,
#  'std': ont::std,
#  'affiliate': ont::affiliate,
#  'navigational-reln': ont::navigational-reln,
#  'credibility-val': ont::credibility-val,
#  'national-identity-val': ont::national-identity-val,
#  'credit-card': ont::credit-card,
#  'not-possible-scale': ont::not-possible-scale,
#  'phys-representation': ont::phys-representation,
#  'polarity-val-positive': ont::polarity-val-positive,
#  'marry': ont::marry,
#  ...}

# %%
from genesis.tools.spacy import nlp
sentence = nlp("I like cats")
tagged = [lookup_all(s) for s in sentence]

for t in tagged:
    print("Lexicon tags:", t[0])
    print("Wordnet derived tags:", t[1])
# Out:
# Lexicon tags: [lex:I.base.person[adolescent]]
# Wordnet derived tags: []
# Lexicon tags: [lex:like.12s123pbase.appreciate[admire], lex:like.12s123pbase.want[covet], lex:like.nom.appreciate[admire], lex:like.nom.want[covet]]
# Wordnet derived tags: [(1.0, lex:like.12s123pbase.want[covet].desire), (1.0, lex:like.12s123pbase.appreciate[admire].like), (1.0, lex:like.12s123pbase.belief-ascription[perceive].see)]
# Lexicon tags: [lex:cats.plur.nonhuman-animal[antelope]]
# Wordnet derived tags: [(1.0, lex:cats.plur.male-person[he].man), (1.0, lex:cats.plur.female-person[female].woman), (1.0, lex:cats.plur.medication[antacid].drug), (0.8, lex:cats.plur.nonhuman-animal[antelope].cat)]

# %%
lex_entry_cats = t[0][0]

# %%
lex_entry_cats.cat
# Out:
# 'plur'

# %%
wclass = lex_entry_cats.wclass
wclass
# Out:
# nonhuman-animal[antelope,ape,bat,bear,beaver,beefalo,beluga whale,bison,boar,bowhead whale,buffalo,camel,caribou,cat,chipmunk,cow,deer,dog,elephant,elk,fox,giraffe,goat,hare,horse,hound,hyena,kitten,lion,llama,monkey,moose,mouse,muskrat,narwhal,opossum,panda,pet,pig,polar bear,porpoise,puppy,rabbit,raccoon,rat,ringed seal,sea lion,seal,sheep,skunk,squirrel,terrier,tiger,walrus,whale,wolf]

# %%
wclass.onttype
# Out:
# 'nonhuman-animal'

# %%
a_template = wclass.templates[0]

# %%
print(a_template.tree_string())
# Out:
# count-pred-templ
#   SYNTAX
#     w::sort
#       w::pred
#     w::agr
#       w::3s
#     w::case
#       ? [any-of]
#         cas
#         w::sub
#         w::obj
#     w::mass
#       w::count
#   ARGUMENTS
